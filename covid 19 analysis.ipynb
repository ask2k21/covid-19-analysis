# %% [markdown]
# # **EDA**

# %%
# import of libraries
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
# import of datasets

data = pd.read_csv("covid19_Confirmed_dataset.csv")

data.head()
# Out:
#   Province/State Country/Region      Lat     Long  1/22/20  1/23/20  1/24/20  \
# 0            NaN    Afghanistan  33.0000  65.0000        0        0        0
# 1            NaN        Albania  41.1533  20.1683        0        0        0
# 2            NaN        Algeria  28.0339   1.6596        0        0        0
# 3            NaN        Andorra  42.5063   1.5218        0        0        0
# 4            NaN         Angola -11.2027  17.8739        0        0        0
#
#    1/25/20  1/26/20  1/27/20  ...  4/21/20  4/22/20  4/23/20  4/24/20  \
# 0        0        0        0  ...     1092     1176     1279     1351
# 1        0        0        0  ...      609      634      663      678
# 2        0        0        0  ...     2811     2910     3007     3127
# 3        0        0        0  ...      717      723      723      731
# 4        0        0        0  ...       24       25       25       25
#
#    4/25/20  4/26/20  4/27/20  4/28/20  4/29/20  4/30/20
# ...

# %%
data.shape
# Out:
# (266, 104)

# %%
# deleting unnecessary columns
data.drop(["Lat","Long"],axis =1,inplace = True)

# %%
data.head()
# Out:
#   Province/State Country/Region  1/22/20  1/23/20  1/24/20  1/25/20  1/26/20  \
# 0            NaN    Afghanistan        0        0        0        0        0
# 1            NaN        Albania        0        0        0        0        0
# 2            NaN        Algeria        0        0        0        0        0
# 3            NaN        Andorra        0        0        0        0        0
# 4            NaN         Angola        0        0        0        0        0
#
#    1/27/20  1/28/20  1/29/20  ...  4/21/20  4/22/20  4/23/20  4/24/20  \
# 0        0        0        0  ...     1092     1176     1279     1351
# 1        0        0        0  ...      609      634      663      678
# 2        0        0        0  ...     2811     2910     3007     3127
# 3        0        0        0  ...      717      723      723      731
# 4        0        0        0  ...       24       25       25       25
#
#    4/25/20  4/26/20  4/27/20  4/28/20  4/29/20  4/30/20
# ...

# %%
data.shape
# Out:
# (266, 102)

# %%
corona_data_aggregated = data.groupby("Country/Region").sum()
# Out:
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_12192\3156974747.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   corona_data_aggregated = data.groupby("Country/Region").sum()

# %%
corona_data_aggregated.head()
# Out:
#                 1/22/20  1/23/20  1/24/20  1/25/20  1/26/20  1/27/20  1/28/20  \
# Country/Region
# Afghanistan           0        0        0        0        0        0        0
# Albania               0        0        0        0        0        0        0
# Algeria               0        0        0        0        0        0        0
# Andorra               0        0        0        0        0        0        0
# Angola                0        0        0        0        0        0        0
#
#                 1/29/20  1/30/20  1/31/20  ...  4/21/20  4/22/20  4/23/20  \
# Country/Region                             ...
# Afghanistan           0        0        0  ...     1092     1176     1279
# Albania               0        0        0  ...      609      634      663
# Algeria               0        0        0  ...     2811     2910     3007
# Andorra               0        0        0  ...      717      723      723
# ...

# %%
corona_data_aggregated.shape
# Out:
# (187, 100)

# %%
# visualize data for countries

corona_data_aggregated.loc["China"].plot()
corona_data_aggregated.loc["India"].plot()
corona_data_aggregated.loc["Pakistan"].plot()

plt.legend()

# %%
corona_data_aggregated.loc["China"].diff().plot()
# Out:
# <Axes: >

# %%
# maximum infection rate
corona_data_aggregated.loc["China"].diff().max()
# Out:
# 15136.0

# %%
countries = corona_data_aggregated.index

max_infection_rate = []

for i in countries:
    max_infection_rate.append(corona_data_aggregated.loc[i].diff().max())
corona_data_aggregated["Max_infection_rate"] = max_infection_rate

# %%
corona_data_aggregated.head()
# Out:
#                 1/22/20  1/23/20  1/24/20  1/25/20  1/26/20  1/27/20  1/28/20  \
# Country/Region
# Afghanistan           0        0        0        0        0        0        0
# Albania               0        0        0        0        0        0        0
# Algeria               0        0        0        0        0        0        0
# Andorra               0        0        0        0        0        0        0
# Angola                0        0        0        0        0        0        0
#
#                 1/29/20  1/30/20  1/31/20  ...  4/22/20  4/23/20  4/24/20  \
# Country/Region                             ...
# Afghanistan           0        0        0  ...     1176     1279     1351
# Albania               0        0        0  ...      634      663      678
# Algeria               0        0        0  ...     2910     3007     3127
# Andorra               0        0        0  ...      723      723      731
# ...

# %%
corona_data = pd.DataFrame(corona_data_aggregated["Max_infection_rate"])

# %%
corona_data
# Out:
#                     Max_infection_rate
# Country/Region
# Afghanistan                      232.0
# Albania                           34.0
# Algeria                          199.0
# Andorra                           43.0
# Angola                             5.0
# ...                                ...
# West Bank and Gaza                66.0
# Western Sahara                     4.0
# Yemen                              5.0
# Zambia                             9.0
# Zimbabwe                           8.0
#
# [187 rows x 1 columns]

# %%
# importing worldhappiness report

happiness_report = pd.read_csv("worldwide_happiness_report.csv")

happiness_report.head()
# Out:
#    Overall rank Country or region  Score  GDP per capita  Social support  \
# 0             1           Finland  7.769           1.340           1.587
# 1             2           Denmark  7.600           1.383           1.573
# 2             3            Norway  7.554           1.488           1.582
# 3             4           Iceland  7.494           1.380           1.624
# 4             5       Netherlands  7.488           1.396           1.522
#
#    Healthy life expectancy  Freedom to make life choices  Generosity  \
# 0                    0.986                         0.596       0.153
# 1                    0.996                         0.592       0.252
# 2                    1.028                         0.603       0.271
# 3                    1.026                         0.591       0.354
# 4                    0.999                         0.557       0.322
#
#    Perceptions of corruption
# 0                      0.393
# 1                      0.410
# ...

# %%
# drop useless columns
list = ["Overall rank","Score","Generosity","Perceptions of corruption"]

happiness_report.drop(list,axis =1,inplace = True)

# %%
happiness_report.head()
# Out:
#   Country or region  GDP per capita  Social support  Healthy life expectancy  \
# 0           Finland           1.340           1.587                    0.986
# 1           Denmark           1.383           1.573                    0.996
# 2            Norway           1.488           1.582                    1.028
# 3           Iceland           1.380           1.624                    1.026
# 4       Netherlands           1.396           1.522                    0.999
#
#    Freedom to make life choices
# 0                         0.596
# 1                         0.592
# 2                         0.603
# 3                         0.591
# 4                         0.557

# %%
happiness_report.set_index("Country or region",inplace=True)
happiness_report.head()
# Out:
#                    GDP per capita  Social support  Healthy life expectancy  \
# Country or region
# Finland                     1.340           1.587                    0.986
# Denmark                     1.383           1.573                    0.996
# Norway                      1.488           1.582                    1.028
# Iceland                     1.380           1.624                    1.026
# Netherlands                 1.396           1.522                    0.999
#
#                    Freedom to make life choices
# Country or region
# Finland                                   0.596
# Denmark                                   0.592
# Norway                                    0.603
# Iceland                                   0.591
# Netherlands                               0.557

# %%
data1 = corona_data.join(happiness_report, how = "inner")

data1
# Out:
#              Max_infection_rate  GDP per capita  Social support  \
# Afghanistan               232.0           0.350           0.517
# Albania                    34.0           0.947           0.848
# Algeria                   199.0           1.002           1.160
# Argentina                 291.0           1.092           1.432
# Armenia                   134.0           0.850           1.055
# ...                         ...             ...             ...
# Venezuela                  29.0           0.960           1.427
# Vietnam                    19.0           0.741           1.346
# Yemen                       5.0           0.287           1.163
# Zambia                      9.0           0.578           1.058
# Zimbabwe                    8.0           0.366           1.114
#
#              Healthy life expectancy  Freedom to make life choices
# Afghanistan                    0.361                         0.000
# ...

# %%
data1.corr()
# Out:
#                               Max_infection_rate  GDP per capita  \
# Max_infection_rate                      1.000000        0.250118
# GDP per capita                          0.250118        1.000000
# Social support                          0.191958        0.759468
# Healthy life expectancy                 0.289263        0.863062
# Freedom to make life choices            0.078196        0.394603
#
#                               Social support  Healthy life expectancy  \
# Max_infection_rate                  0.191958                 0.289263
# GDP per capita                      0.759468                 0.863062
# Social support                      1.000000                 0.765286
# Healthy life expectancy             0.765286                 1.000000
# Freedom to make life choices        0.456246                 0.427892
#
#                               Freedom to make life choices
# Max_infection_rate                                0.078196
# ...

# %%
sns.heatmap(data1.corr())
# Out:
# <Axes: >

# %%
sns.scatterplot(x=data1["GDP per capita"],y=data1["Max_infection_rate"])
# Out:
# <Axes: xlabel='GDP per capita', ylabel='Max_infection_rate'>

# %%
x = data1["GDP per capita"]
y = data1["Max_infection_rate"]

sns.scatterplot(x=data1["GDP per capita"],y=np.log(data1["Max_infection_rate"]))
# Out:
# <Axes: xlabel='GDP per capita', ylabel='Max_infection_rate'>

# %%
sns.regplot(x=data1["GDP per capita"],y=np.log(data1["Max_infection_rate"]))
# Out:
# <Axes: xlabel='GDP per capita', ylabel='Max_infection_rate'>

# %%
sns.scatterplot(x=data1["Social support"],y=np.log(data1["Max_infection_rate"]))
# Out:
# <Axes: xlabel='Social support', ylabel='Max_infection_rate'>

# %%
sns.regplot(x=data1["Social support"],y=np.log(data1["Max_infection_rate"]))
# Out:
# <Axes: xlabel='Social support', ylabel='Max_infection_rate'>

# %%
sns.scatterplot(x=data1["Healthy life expectancy"],y=np.log(data1["Max_infection_rate"]))
# Out:
# <Axes: xlabel='Healthy life expectancy', ylabel='Max_infection_rate'>

# %%
sns.regplot(x=data1["Healthy life expectancy"],y=np.log(data1["Max_infection_rate"]))
# Out:
# <Axes: xlabel='Healthy life expectancy', ylabel='Max_infection_rate'>

# %%
sns.scatterplot(x=data1["Freedom to make life choices"],y=np.log(data1["Max_infection_rate"]))
# Out:
# <Axes: xlabel='Freedom to make life choices', ylabel='Max_infection_rate'>

# %%
sns.regplot(x=data1["Freedom to make life choices"],y=np.log(data1["Max_infection_rate"]))
# Out:
# <Axes: xlabel='Freedom to make life choices', ylabel='Max_infection_rate'>
